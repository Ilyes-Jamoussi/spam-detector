# %% [markdown]
# # 🛡️ Spam Detector — Transformer Training (GPU)
#
# **Steps:** Run all cells → Wait ~30-60 min → Download model files

# %%
# 1. Check GPU
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
else:
    print('⚠️ Go to Runtime > Change runtime type > GPU')

# %%
# 2. Clone repo
# !git clone https://github.com/IlyesJamoussi/spam-detector.git
# %cd spam-detector

# %%
# 3. Install dependencies
# !pip install torch pandas numpy scikit-learn tqdm -q

# %%
# 4. Download & prepare datasets
# !python src/prepare_data.py

# %%
# 5. Train the full Transformer model
# !python src/train.py

# %%
# 6. Download trained model
# !zip -r trained_model.zip models/
from google.colab import files
files.download('trained_model.zip')
